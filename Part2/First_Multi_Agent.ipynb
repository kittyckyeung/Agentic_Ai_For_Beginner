# %%
#!pip install crewai crewai_tools==0.1.6 langchain_community==0.0.29

# %%
#!pip show crewai

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %%
import crewai
from crewai import Agent, Task, Crew

# %%
# Load the .env file from local
import openai
from dotenv import load_dotenv
env_path = r'C:\Users\user\Desktop\Coding\.env'
load_dotenv(env_path)
# Out:
# True

# %%
import os
os.environ["OPENAI_MODEL_NAME"] = 'gpt-4'

# %%
#1- Chef
chef = Agent(
    role="chef",
    goal="Give 5 different receipes using ingredients : {ingredients}",
    backstory="You're  a Chef who has experience on cooking delicious foods"
              "Your expertice lies in recommeding some new foods to the customers"
              "Please generate and give receipe of 5 different foods using this ingredients : {ingredients} "
              "describing stepwise process, time to cook, other ingredients needed and calorie count"
              "Your recipe will be critically analyzed by nutritutionist to recommend food for diabetes patients ",
	verbose=True
)

# %%
2# Nutritionist
nutritionist = Agent(
    role="nutritionist",
    goal="Critically analyze the recipe given by chef using these ingredients: {ingredients}",
    backstory="You're a nutritionist and have good knowledge on working with Diabetic patients "
              "There are recipe recommended by chef using these ingredients : {ingredients}. "
              "please critically analyze the recipe and suggest best food out of goven 5 for Diabetic patients"
              "Also give reasons why you dont recommend other 4 receips and choose this one",
    verbose=True
)

# %%
cook = Task(
    description=(
        "1. Write receipe of 5 different foods using these ingredients  : {ingredients}.\n"
    ),
    expected_output="5 different receipes using {ingredients}"
                    "Stepwise guide to cook"
                    "List of all additional ingredients required for cooking"
                    "The expected taste of the food",
    agent=chef,
)

# %%
recommend = Task(
    description=(
        "1. Read the receipes provided by chef using {ingredients} \n"
        "2. critically analyze all receipes keeping in mind what should suit to diabetic patients.\n"
        "3. Suggest one best food out of all 5 receipes given by chef.\n"
        "4. Prove that other 4 receipes suggested by chef is not good for diabetic patients.\n"
        
    ),
    expected_output="A well-written critical pointwise analysis of all 5 recipes using {ingredients}"
                    "Suggest one receipe to diabetic patients based on your own knowledge and evidence "
                    "Reject all other 4 receipes with knowledge and evidence "
                    "Finally, give the stepwoise receipe of what you selected and a nice message",
    agent=nutritionist,
)

# %%
crewaman = Crew(
    agents=[chef,nutritionist],
    tasks=[cook, recommend],
    verbose=True
)

# %%
result = crewaman.kickoff(inputs={"ingredients": "chicken"})
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: f00c95e3-8fc4-4e10-ae68-8bc9be519368                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: 1. Write receipe of 5 different foods using these ingredients  : chicken.                                │
# │                                                                                                                 │
# │  ID: 239b5d7e-b86e-41a9-b623-080899af3dac                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: chef                                                                                                    │
# │                                                                                                                 │
# │  Task: 1. Write receipe of 5 different foods using these ingredients  : chicken.                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: chef                                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Sure, here are the recipes:                                                                                    │
# │                                                                                                                 │
# │  1) Chicken Vegetable Soup:                                                                                     │
# │  Ingredients:                                                                                                   │
# │  - 500g chicken, diced                                                                                          │
# │  - 1 onion, chopped                                                                                             │
# │  - 2 carrots, chopped                                                                                           │
# │  - 2 celery stalks, chopped                                                                                     │
# │  - 5 cups of chicken stock                                                                                      │
# │  - Salt and pepper to taste                                                                                     │
# │                                                                                                                 │
# │  Steps:                                                                                                         │
# │  - In a large pot, heat chicken until fully cooked. Once done, remove the chicken and set aside.                │
# │  - In the same pot, add the onion, carrots, and celery, cook until they begin to soften.                        │
# │  - Return the chicken to the pot and add chicken stock. Bring the mixture to a boil, then reduce to a simmer.   │
# │  - Cook for about 20-30 minutes until the vegetables are tender.                                                │
# │  - Season with salt and pepper to own liking.                                                                   │
# │                                                                                                                 │
# │  Cooking Time: 45-60 mins                                                                                       │
# │  Calories: appr 120cal per serving                                                                              │
# │                                                                                                                 │
# │  2) Grilled Chicken Salad:                                                                                      │
# │  Ingredients:                                                                                                   │
# │  - 4 chicken breasts                                                                                            │
# │  - Mixed salad leaves                                                                                           │
# │  - 1 cucumber, sliced                                                                                           │
# │  - 2 tomatoes, chopped                                                                                          │
# │  - Olive oil, for dressing                                                                                      │
# │  - Lemon juice, for dressing                                                                                    │
# │  - Salt and pepper to taste                                                                                     │
# │                                                                                                                 │
# │  Steps:                                                                                                         │
# │  - Grill the chicken breasts on a preheated grill until fully cooked.                                           │
# │  - In a large bowl, combine salad leaves, cucumber, and tomatoes.                                               │
# │  - Once the chicken is cooked, slice it and add it to the salad.                                                │
# │  - Prepare the dressing by mixing olive oil, lemon juice, salt, and pepper. Pour over the salad and toss to     │
# │  mix.                                                                                                           │
# │                                                                                                                 │
# │  Cooking Time: 30-40 mins                                                                                       │
# │  Calories: appr 250cal per serving                                                                              │
# │                                                                                                                 │
# │  3) Baked Chicken with Cauliflower:                                                                             │
# │  Ingredients:                                                                                                   │
# │  - 4 chicken breasts                                                                                            │
# │  - 1 large head of cauliflower, cut into florets                                                                │
# │  - Olive oil                                                                                                    │
# │  - Salt and pepper                                                                                              │
# │  - Oregano for seasoning                                                                                        │
# │                                                                                                                 │
# │  Steps:                                                                                                         │
# │  - Preheat oven to 200°C.                                                                                       │
# │  - Prepare a baking dish by coating it with olive oil.                                                          │
# │  - Place chicken and cauliflower in the baking dish. Drizzle with olive oil and season with salt, pepper, and   │
# │  oregano.                                                                                                       │
# │  - Bake for about 30 minutes or until chicken is fully cooked and cauliflower is tender.                        │
# │                                                                                                                 │
# │  Cooking Time: 30-40 mins                                                                                       │
# │  Calories: appr 300cal per serving                                                                              │
# │                                                                                                                 │
# │  4) Chicken Stir Fry:                                                                                           │
# │  Ingredients:                                                                                                   │
# │  - 500g chicken, diced                                                                                          │
# │  - 1 bell pepper, diced                                                                                         │
# │  - 1 onion, diced                                                                                               │
# │  - 1 carrot, thinly sliced                                                                                      │
# │  - 1 tsp soy sauce                                                                                              │
# │  - Olive oil                                                                                                    │
# │                                                                                                                 │
# │  Steps:                                                                                                         │
# │  - In a pan, heat some oil and cook chicken until fully cooked. Once done, remove and set aside.                │
# │  - In the same pan, add bell pepper, onion, and carrot. Stir fry until they are tender.                         │
# │  - Return the chicken to the pan and add soy sauce. Stir the mixture well.                                      │
# │                                                                                                                 │
# │  Cooking Time: 20 mins                                                                                          │
# │  Calories: appr 150cal per serving                                                                              │
# │                                                                                                                 │
# │  5) Chicken and Broccoli Stir-Fry:                                                                              │
# │  Ingredients:                                                                                                   │
# │  - 4 boneless skinless chicken breasts                                                                          │
# │  - 1 large head of broccoli, chopped into florets                                                               │
# │  - 2 tbsp olive oil                                                                                             │
# │  - 1/4 cup low sodium soy sauce                                                                                 │
# │  - 2 garlic cloves, minced                                                                                      │
# │  - Salt and pepper to taste                                                                                     │
# │  - 1/2 cup chicken broth                                                                                        │
# │                                                                                                                 │
# │  Steps:                                                                                                         │
# │  - Dice the chicken into bite-sized pieces.                                                                     │
# │  - Heat the olive oil in a pan on medium heat. Add the chicken and cook until golden on both sides.             │
# │  - Add broccoli, garlic, soy sauce, salt, pepper, and chicken broth.                                            │
# │  - Stir everything together and cover the pan. Cook for 10-15 minutes until the broccoli is tender and the      │
# │  chicken is fully cooked.                                                                                       │
# │                                                                                                                 │
# │  Cooking Time: 30 min                                                                                           │
# │  Calories: appr 200cal per serving                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 1. Write receipe of 5 different foods using these ingredients  : chicken.                                │
# │                                                                                                                 │
# │  Agent: chef                                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: 1. Read the receipes provided by chef using chicken                                                      │
# │  2. critically analyze all receipes keeping in mind what should suit to diabetic patients.                      │
# │  3. Suggest one best food out of all 5 receipes given by chef.                                                  │
# │  4. Prove that other 4 receipes suggested by chef is not good for diabetic patients.                            │
# │                                                                                                                 │
# │  ID: a9f1ee62-c333-4418-bc01-becc22d52db5                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: nutritionist                                                                                            │
# │                                                                                                                 │
# │  Task: 1. Read the receipes provided by chef using chicken                                                      │
# │  2. critically analyze all receipes keeping in mind what should suit to diabetic patients.                      │
# │  3. Suggest one best food out of all 5 receipes given by chef.                                                  │
# │  4. Prove that other 4 receipes suggested by chef is not good for diabetic patients.                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: nutritionist                                                                                            │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  After carefully reviewing the given chef's recommendations, I would recommend the "Grilled Chicken Salad" for  │
# │  diabetic patients. Here’s my analysis:                                                                         │
# │                                                                                                                 │
# │  1) Chicken Vegetable Soup: This recipe is based on a chicken broth and includes a variety of vegetables.       │
# │  While this recipe lacks complex carbohydrates and fiber-rich ingredients which are beneficial for diabetic     │
# │  individuals, too much sodium can also have a negative effect. Many commercial chicken broths can be high in    │
# │  sodium which can cause fluctuations in blood pressure, something that many diabetic individuals are already    │
# │  at risk for.                                                                                                   │
# │                                                                                                                 │
# │  2) Grilled Chicken Salad: It is ideal for someone with diabetes because it contains a good balance of protein  │
# │  (from the chicken), fiber (from the salad leaves and vegetables), and healthy fats (from the olive oil).       │
# │  Protein is essential for repairing body tissues and maintaining a healthy immune system, while dietary fiber   │
# │  can help to control blood sugar levels by slowing down digestion and preventing rapid rises in blood sugar     │
# │  after meals. Olive oil is a source of monounsaturated fat, which can help reduce levels of 'bad' LDL           │
# │  cholesterol and increase 'good' HDL cholesterol.                                                               │
# │                                                                                                                 │
# │  3) Baked Chicken with Cauliflower: While this recipe is a lower carb option with the presence of cauliflower,  │
# │  it could lead to higher blood sugar levels due to the lack of balance between the macros: carbohydrates and    │
# │  protein. We need a balanced plate for diabetic individuals. Also, too much consumption of animal proteins may  │
# │  not be beneficial for diabetic patients as suggested in some studies.                                          │
# │                                                                                                                 │
# │  4) Chicken Stir Fry: This recipe contains a variety of vegetables and lean protein, but the use of soy sauce   │
# │  may raise some concern. Soy sauce is high in sodium, which can lead to increased blood pressure and potential  │
# │  complications with diabetes. Moreover, this dish lacks a source of complex carbohydrates, leading to           │
# │  imbalanced macros.                                                                                             │
# │                                                                                                                 │
# │  5) Chicken and Broccoli Stir-Fry: This dish has lean protein and a vegetable. However, like the stir fry, it   │
# │  also contains soy sauce, which is high in sodium. It also lacks a fiber-rich carbohydrate source, leading to   │
# │  a less balanced meal for a diabetic patient.                                                                   │
# │                                                                                                                 │
# │  The recommended Grilled Chicken Salad recipe is as follows:                                                    │
# │                                                                                                                 │
# │  Ingredients:                                                                                                   │
# │  - 4 chicken breasts                                                                                            │
# │  - Mixed salad leaves                                                                                           │
# │  - 1 cucumber, sliced                                                                                           │
# │  - 2 tomatoes, chopped                                                                                          │
# │  - Olive oil, for dressing                                                                                      │
# │  - Lemon juice, for dressing                                                                                    │
# │  - Salt and pepper to taste                                                                                     │
# │                                                                                                                 │
# │  Steps:                                                                                                         │
# │  - Grill the chicken breasts on a preheated grill until fully cooked.                                           │
# │  - In a large bowl, combine salad leaves, cucumber, and tomatoes.                                               │
# │  - Once the chicken is cooked, slice it and add it to the salad.                                                │
# │  - Prepare the dressing by mixing olive oil, lemon juice, salt, sand pepper. Pour over the salad and toss to    │
# │  mix.                                                                                                           │
# │                                                                                                                 │
# │  Eat well, manage your diabetes, and remember, the key to good health is a balanced diet!                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 1. Read the receipes provided by chef using chicken                                                      │
# │  2. critically analyze all receipes keeping in mind what should suit to diabetic patients.                      │
# │  3. Suggest one best food out of all 5 receipes given by chef.                                                  │
# │  4. Prove that other 4 receipes suggested by chef is not good for diabetic patients.                            │
# │                                                                                                                 │
# │  Agent: nutritionist                                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────────── Execution Traces ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  🔍 Detailed execution traces are available!                                                                    │
# │                                                                                                                 │
# │  View insights including:                                                                                       │
# │    • Agent decision-making process                                                                              │
# │    • Task execution flow and timing                                                                             │
# │    • Tool usage details                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Would you like to view your execution traces? [y/N] (20s timeout):
# ┌───────────────────────── Tracing Preference Saved ──────────────────────────┐
# │                                                                             │
# │  Info: Tracing has been disabled.                                           │
# │                                                                             │
# │  Your preference has been saved. Future Crew/Flow executions will not       │
# │  collect traces.                                                            │
# │                                                                             │
# │  To enable tracing later, do any one of these:                              │
# │  • Set tracing=True in your Crew/Flow code                                  │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file              │
# │  • Run: crewai traces enable                                                │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: f00c95e3-8fc4-4e10-ae68-8bc9be519368                                                                       │
# │  Final Output: After carefully reviewing the given chef's recommendations, I would recommend the "Grilled       │
# │  Chicken Salad" for diabetic patients. Here’s my analysis:                                                      │
# │                                                                                                                 │
# │  1) Chicken Vegetable Soup: This recipe is based on a chicken broth and includes a variety of vegetables.       │
# │  While this recipe lacks complex carbohydrates and fiber-rich ingredients which are beneficial for diabetic     │
# │  individuals, too much sodium can also have a negative effect. Many commercial chicken broths can be high in    │
# │  sodium which can cause fluctuations in blood pressure, something that many diabetic individuals are already    │
# │  at risk for.                                                                                                   │
# │                                                                                                                 │
# │  2) Grilled Chicken Salad: It is ideal for someone with diabetes because it contains a good balance of protein  │
# │  (from the chicken), fiber (from the salad leaves and vegetables), and healthy fats (from the olive oil).       │
# │  Protein is essential for repairing body tissues and maintaining a healthy immune system, while dietary fiber   │
# │  can help to control blood sugar levels by slowing down digestion and preventing rapid rises in blood sugar     │
# │  after meals. Olive oil is a source of monounsaturated fat, which can help reduce levels of 'bad' LDL           │
# │  cholesterol and increase 'good' HDL cholesterol.                                                               │
# │                                                                                                                 │
# │  3) Baked Chicken with Cauliflower: While this recipe is a lower carb option with the presence of cauliflower,  │
# │  it could lead to higher blood sugar levels due to the lack of balance between the macros: carbohydrates and    │
# │  protein. We need a balanced plate for diabetic individuals. Also, too much consumption of animal proteins may  │
# │  not be beneficial for diabetic patients as suggested in some studies.                                          │
# │                                                                                                                 │
# │  4) Chicken Stir Fry: This recipe contains a variety of vegetables and lean protein, but the use of soy sauce   │
# │  may raise some concern. Soy sauce is high in sodium, which can lead to increased blood pressure and potential  │
# │  complications with diabetes. Moreover, this dish lacks a source of complex carbohydrates, leading to           │
# │  imbalanced macros.                                                                                             │
# │                                                                                                                 │
# │  5) Chicken and Broccoli Stir-Fry: This dish has lean protein and a vegetable. However, like the stir fry, it   │
# │  also contains soy sauce, which is high in sodium. It also lacks a fiber-rich carbohydrate source, leading to   │
# │  a less balanced meal for a diabetic patient.                                                                   │
# │                                                                                                                 │
# │  The recommended Grilled Chicken Salad recipe is as follows:                                                    │
# │                                                                                                                 │
# │  Ingredients:                                                                                                   │
# │  - 4 chicken breasts                                                                                            │
# │  - Mixed salad leaves                                                                                           │
# │  - 1 cucumber, sliced                                                                                           │
# │  - 2 tomatoes, chopped                                                                                          │
# │  - Olive oil, for dressing                                                                                      │
# │  - Lemon juice, for dressing                                                                                    │
# │  - Salt and pepper to taste                                                                                     │
# │                                                                                                                 │
# │  Steps:                                                                                                         │
# │  - Grill the chicken breasts on a preheated grill until fully cooked.                                           │
# │  - In a large bowl, combine salad leaves, cucumber, and tomatoes.                                               │
# │  - Once the chicken is cooked, slice it and add it to the salad.                                                │
# │  - Prepare the dressing by mixing olive oil, lemon juice, salt, sand pepper. Pour over the salad and toss to    │
# │  mix.                                                                                                           │
# │                                                                                                                 │
# │  Eat well, manage your diabetes, and remember, the key to good health is a balanced diet!                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
