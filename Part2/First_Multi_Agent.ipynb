# %%
#!pip install crewai crewai_tools==0.1.6 langchain_community==0.0.29

# %%
#!pip show crewai

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %%
import crewai
from crewai import Agent, Task, Crew

# %%
# Load the .env file from local
import openai
from dotenv import load_dotenv
env_path = r'C:\Users\user\Desktop\Coding\.env'
load_dotenv(env_path)
# Out:
# True

# %%
import os
os.environ["OPENAI_MODEL_NAME"] = 'gpt-4'

# %%
#1- Chef
chef = Agent(
    role="chef",
    goal="Give 5 different receipes using ingredients : {ingredients}",
    backstory="You're  a Chef who has experience on cooking delicious foods"
              "Your expertice lies in recommeding some new foods to the customers"
              "Please generate and give receipe of 5 different foods using this ingredients : {ingredients} "
              "describing stepwise process, time to cook, other ingredients needed and calorie count"
              "Your recipe will be critically analyzed by nutritutionist to recommend food for diabetes patients ",
	verbose=True
)

# %%
2# Nutritionist
nutritionist = Agent(
    role="nutritionist",
    goal="Critically analyze the recipe given by chef using these ingredients: {ingredients}",
    backstory="You're a nutritionist and have good knowledge on working with Diabetic patients "
              "There are recipe recommended by chef using these ingredients : {ingredients}. "
              "please critically analyze the recipe and suggest best food out of goven 5 for Diabetic patients"
              "Also give reasons why you dont recommend other 4 receips and choose this one",
    verbose=True
)

# %%
cook = Task(
    description=(
        "1. Write receipe of 5 different foods using these ingredients  : {ingredients}.\n"
    ),
    expected_output="5 different receipes using {ingredients}"
                    "Stepwise guide to cook"
                    "List of all additional ingredients required for cooking"
                    "The expected taste of the food",
    agent=chef,
)

# %%
recommend = Task(
    description=(
        "1. Read the receipes provided by chef using {ingredients} \n"
        "2. critically analyze all receipes keeping in mind what should suit to diabetic patients.\n"
        "3. Suggest one best food out of all 5 receipes given by chef.\n"
        "4. Prove that other 4 receipes suggested by chef is not good for diabetic patients.\n"
        
    ),
    expected_output="A well-written critical pointwise analysis of all 5 recipes using {ingredients}"
                    "Suggest one receipe to diabetic patients based on your own knowledge and evidence "
                    "Reject all other 4 receipes with knowledge and evidence "
                    "Finally, give the stepwoise receipe of what you selected and a nice message",
    agent=nutritionist,
)

# %%
crewaman = Crew(
    agents=[chef,nutritionist],
    tasks=[cook, recommend],
    verbose=True
)

# %%
result = crewaman.kickoff(inputs={"ingredients": "chicken"})
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 6183ad8f-69eb-45c9-a88d-726087dfc2b4                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: 1. Write receipe of 5 different foods using these ingredients  : chicken.                                │
# │                                                                                                                 │
# │  ID: 0877e6a2-bdc9-4dcc-9f48-fed51a6f6bf3                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: chef                                                                                                    │
# │                                                                                                                 │
# │  Task: 1. Write receipe of 5 different foods using these ingredients  : chicken.                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: chef                                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  1. Grilled Chicken Breast Salad                                                                                │
# │  Steps:                                                                                                         │
# │     1. Marinate chicken breasts with olive oil, garlic, salt, and pepper for 20 minutes.                        │
# │     2. Grill the chicken on a preheated grill for 6-8 minutes each side until they are cooked thoroughly.       │
# │     3. Prepare the salad by combining mixed greens, cherry tomatoes, cucumber, and avocado.                     │
# │     4. Cut the cooked chicken into slices and add to the salad.                                                 │
# │     5. Drizzle low fat vinaigrette over the salad and serve.                                                    │
# │  Ingredients: Chicken breasts, olive oil, garlic, salt, pepper, mixed greens, cherry tomatoes, cucumber,        │
# │  avocado, low-fat vinaigrette.                                                                                  │
# │  Estimated Cooking Time: 35 minutes                                                                             │
# │  Calories: Approximately 300 Calories                                                                           │
# │                                                                                                                 │
# │  2. Chicken Stir-fry                                                                                            │
# │  Steps:                                                                                                         │
# │     1. Marinate diced chicken with soy sauce, ginger, and garlic for 20 minutes.                                │
# │     2. Sauté the chicken in a pan with olive oil until fully cooked.                                            │
# │     3. Add mixed bell peppers, broccoli, and carrot and stir-fry for another 5-7 minutes.                       │
# │     4. Serve with steamed brown rice for a balanced meal.                                                       │
# │  Ingredients: Chicken, soy sauce, ginger, garlic, olive oil, mixed bell peppers, broccoli, carrot, brown rice.  │
# │  Estimated Cooking Time: 40 minutes                                                                             │
# │  Calories: Approximately 400 Calories                                                                           │
# │                                                                                                                 │
# │  3. Baked Chicken with Vegetables                                                                               │
# │  Steps:                                                                                                         │
# │     1. Preheat oven to 375°F (190°C).                                                                           │
# │     2. Marinate chicken breasts with lemon juice, olive oil, rosemary, salt, and pepper.                        │
# │     3. Arrange mixed vegetables around the chicken on a baking tray.                                            │
# │     4. Bake for 25-30 minutes or until chicken is fully cooked.                                                 │
# │  Ingredients: Chicken breasts, lemon juice, olive oil, rosemary, mixed vegetables, salt, pepper.                │
# │  Estimated Cooking Time: 40-45 minutes                                                                          │
# │  Calories: Approximately 350 Calories                                                                           │
# │                                                                                                                 │
# │  4. Chicken Soup                                                                                                │
# │  Steps:                                                                                                         │
# │     1. In a large pot, bring chicken, celery, carrots, onions, and garlic to a boil.                            │
# │     2. Reduce heat and simmer until chicken is cooked.                                                          │
# │     3. Remove chicken, shred it, and return to the pot.                                                         │
# │     4. Add herbs and spices and continue to simmer for another 8-10 minutes.                                    │
# │  Ingredients: Chicken, celery, carrots, onions, garlic, herbs and spices.                                       │
# │  Estimated Cooking Time: 60 minutes                                                                             │
# │  Calories: Approximately 250 Calories                                                                           │
# │                                                                                                                 │
# │  5. Chicken Lettuce Wraps                                                                                       │
# │  Steps:                                                                                                         │
# │     1. Sauté minced chicken in a pan with olive oil, garlic, and ginger.                                        │
# │     2. Add diced bell peppers, carrots, and a splash of soy sauce.                                              │
# │     3. Cook until chicken is fully cooked and vegetables are tender.                                            │
# │     4. Serve the mixture in lettuce wraps for a light and healthy meal.                                         │
# │  Ingredients: Chicken, olive oil, garlic, ginger, bell peppers, carrots, soy sauce, lettuce.                    │
# │  Estimated Cooking Time: 30 minutes                                                                             │
# │  Calories: Approximately 200 Calories                                                                           │
# │                                                                                                                 │
# │  All recipes are meant to be low in glycemic index and hence suitable for diabetic patients with the            │
# │  appropriate portion sizes.                                                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 1. Write receipe of 5 different foods using these ingredients  : chicken.                                │
# │                                                                                                                 │
# │  Agent: chef                                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: 1. Read the receipes provided by chef using chicken                                                      │
# │  2. critically analyze all receipes keeping in mind what should suit to diabetic patients.                      │
# │  3. Suggest one best food out of all 5 receipes given by chef.                                                  │
# │  4. Prove that other 4 receipes suggested by chef is not good for diabetic patients.                            │
# │                                                                                                                 │
# │  ID: 20e12dba-30e0-4425-867b-20d31086336f                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: nutritionist                                                                                            │
# │                                                                                                                 │
# │  Task: 1. Read the receipes provided by chef using chicken                                                      │
# │  2. critically analyze all receipes keeping in mind what should suit to diabetic patients.                      │
# │  3. Suggest one best food out of all 5 receipes given by chef.                                                  │
# │  4. Prove that other 4 receipes suggested by chef is not good for diabetic patients.                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: nutritionist                                                                                            │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Analyzing all the given recipes, the best suited for diabetic patients is "Grilled Chicken Breast Salad".      │
# │                                                                                                                 │
# │  Here's why:                                                                                                    │
# │                                                                                                                 │
# │  1. Grilled Chicken Breast Salad: This recipe uses lean protein (chicken breast) and a wide variety of fresh    │
# │  vegetables including mixed greens, cherry tomatoes, cucumber, and avocado. These ingredients are low in        │
# │  glycemic index, low in fat, and high in fiber which is good for diabetics as they help to control blood sugar  │
# │  levels. Olive oil is a healthy fat that helps to regulate blood sugar levels and the recipe only uses a small  │
# │  amount of it. The low-fat vinaigrette drizzled over the salad adds flavor without adding a lot of calories or  │
# │  Carbohydrates.                                                                                                 │
# │                                                                                                                 │
# │  On the other hand, the reasons for not recommending the other four recipes are as follows:                     │
# │                                                                                                                 │
# │  2. Chicken Stir-fry: Although this recipe is packed with lean protein and vegetables, it is served with brown  │
# │  rice which can raise blood sugar levels in diabetics. Even though brown rice is a healthier option than white  │
# │  rice, it is still high in carbohydrates which can spike insulin levels.                                        │
# │                                                                                                                 │
# │  3. Baked Chicken with Vegetables: Again, a good combination of lean protein and assorted vegetables, but the   │
# │  use of lemon juice can raise concerns. Lemon juice can affect insulin levels and hence might not be a          │
# │  desirable ingredient for diabetics.                                                                            │
# │                                                                                                                 │
# │  4. Chicken Soup: While chicken soup is comforting and includes low-carb vegetables, the liquid nature of soup  │
# │  may not be as satiating as other meals. This may cause the person to feel hungry quicker and seek additional   │
# │  food, thus increasing their daily caloric and carbohydrate intake.                                             │
# │                                                                                                                 │
# │  5. Chicken Lettuce Wraps: This recipe is low calorie and light. However, the use of soy sauce might increase   │
# │  the sodium intake which isn't beneficial for diabetic patients who are often at higher risk of heart           │
# │  diseases.                                                                                                      │
# │                                                                                                                 │
# │  Therefore, with the above reasons listed, I'd recommend the Grilled Chicken Breast Salad for diabetic          │
# │  patients. Here's the recipe:                                                                                   │
# │                                                                                                                 │
# │  1. Marinate chicken breasts with olive oil, garlic, salt, and pepper for 20 minutes.                           │
# │  2. Grill the chicken on a preheated grill for 6-8 minutes each side until cooked thoroughly.                   │
# │  3. Prepare the salad by combining mixed greens, cherry tomatoes, cucumber, and avocado.                        │
# │  4. Cut the cooked chicken into slices and add to the salad.                                                    │
# │  5. Drizzle low fat vinaigrette over the salad and serve.                                                       │
# │                                                                                                                 │
# │  Remember, it's not just about managing your blood sugar, but also enjoying your food. Happy eating!            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 1. Read the receipes provided by chef using chicken                                                      │
# │  2. critically analyze all receipes keeping in mind what should suit to diabetic patients.                      │
# │  3. Suggest one best food out of all 5 receipes given by chef.                                                  │
# │  4. Prove that other 4 receipes suggested by chef is not good for diabetic patients.                            │
# │                                                                                                                 │
# │  Agent: nutritionist                                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 6183ad8f-69eb-45c9-a88d-726087dfc2b4                                                                       │
# │  Final Output: Analyzing all the given recipes, the best suited for diabetic patients is "Grilled Chicken       │
# │  Breast Salad".                                                                                                 │
# │                                                                                                                 │
# │  Here's why:                                                                                                    │
# │                                                                                                                 │
# │  1. Grilled Chicken Breast Salad: This recipe uses lean protein (chicken breast) and a wide variety of fresh    │
# │  vegetables including mixed greens, cherry tomatoes, cucumber, and avocado. These ingredients are low in        │
# │  glycemic index, low in fat, and high in fiber which is good for diabetics as they help to control blood sugar  │
# │  levels. Olive oil is a healthy fat that helps to regulate blood sugar levels and the recipe only uses a small  │
# │  amount of it. The low-fat vinaigrette drizzled over the salad adds flavor without adding a lot of calories or  │
# │  Carbohydrates.                                                                                                 │
# │                                                                                                                 │
# │  On the other hand, the reasons for not recommending the other four recipes are as follows:                     │
# │                                                                                                                 │
# │  2. Chicken Stir-fry: Although this recipe is packed with lean protein and vegetables, it is served with brown  │
# │  rice which can raise blood sugar levels in diabetics. Even though brown rice is a healthier option than white  │
# │  rice, it is still high in carbohydrates which can spike insulin levels.                                        │
# │                                                                                                                 │
# │  3. Baked Chicken with Vegetables: Again, a good combination of lean protein and assorted vegetables, but the   │
# │  use of lemon juice can raise concerns. Lemon juice can affect insulin levels and hence might not be a          │
# │  desirable ingredient for diabetics.                                                                            │
# │                                                                                                                 │
# │  4. Chicken Soup: While chicken soup is comforting and includes low-carb vegetables, the liquid nature of soup  │
# │  may not be as satiating as other meals. This may cause the person to feel hungry quicker and seek additional   │
# │  food, thus increasing their daily caloric and carbohydrate intake.                                             │
# │                                                                                                                 │
# │  5. Chicken Lettuce Wraps: This recipe is low calorie and light. However, the use of soy sauce might increase   │
# │  the sodium intake which isn't beneficial for diabetic patients who are often at higher risk of heart           │
# │  diseases.                                                                                                      │
# │                                                                                                                 │
# │  Therefore, with the above reasons listed, I'd recommend the Grilled Chicken Breast Salad for diabetic          │
# │  patients. Here's the recipe:                                                                                   │
# │                                                                                                                 │
# │  1. Marinate chicken breasts with olive oil, garlic, salt, and pepper for 20 minutes.                           │
# │  2. Grill the chicken on a preheated grill for 6-8 minutes each side until cooked thoroughly.                   │
# │  3. Prepare the salad by combining mixed greens, cherry tomatoes, cucumber, and avocado.                        │
# │  4. Cut the cooked chicken into slices and add to the salad.                                                    │
# │  5. Drizzle low fat vinaigrette over the salad and serve.                                                       │
# │                                                                                                                 │
# │  Remember, it's not just about managing your blood sugar, but also enjoying your food. Happy eating!            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
