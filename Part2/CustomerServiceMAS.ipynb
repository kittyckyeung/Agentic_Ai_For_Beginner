# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %%
#!pip install crewai==0.28.8 crewai_tools==0.1.6 langchain_community==0.0.29

# %%
# Load the .env file from local
import openai
from dotenv import load_dotenv
env_path = r'C:\Users\user\Desktop\Coding\.env'
load_dotenv(env_path)
# Out:
# True

# %%
from crewai import Agent, Task, Crew

# %%
#Define first Agent(Level 1)
customer_assist_agent = Agent(
    role="Customer Care Specialist",
    goal="Deliver the most courteous and effective "
         "customer support on your team.",
    backstory=(
        "You are a valued team member at Crew AI (https://docs.crewai.com/introduction) "
        "and currently assigned to assist {customer}, a crucial client "
        "for the company."
        "Your mission is to ensure the highest quality of support!"
        "Provide detailed and thorough responses, "
        "avoiding any assumptions."
    ),
    allow_delegation=False,
    verbose=True
)

# %%
#Define second agent(Level 2)
quality_check_agent = Agent(
    role="Support Quality Analyst",
    goal="Be recognized for ensuring the highest "
         "standards of support quality in your team.",
    backstory=(
        "You are a key contributor at CrewAI (https://docs.crewai.com/introduction), "
        "working alongside your team to review a support request from {customer}. "
        "Your responsibility is to ensure that the Customer Care Specialist "
        "delivers top-notch service.\n"
        "It’s your duty to confirm that all responses are thorough, "
        "accurate, and free of assumptions."
    ),
    verbose=True
)

# %%
from crewai_tools import SerperDevTool, \
                         ScrapeWebsiteTool, \
                         WebsiteSearchTool

# %%
docs_scrape_tool = ScrapeWebsiteTool(
    website_url="https://docs.crewai.com/introduction",config={}
)

# %%
customer_query_task = Task(
    description=(
        "{customer} has submitted a critical request:\n"
        "{inquiry}\n\n"
        "{person} from {customer} initiated the inquiry. "
        "Leverage all available resources and knowledge to "
        "deliver outstanding support."
        "Your goal is to provide a thorough and accurate resolution "
        "to the customer's question."
    ),
    expected_output=(
        "A comprehensive and well-researched response to the customer's inquiry "
        "that addresses every aspect of their concern.\n"
        "The response must reference all the tools and information sources used, "
        "including external materials or solutions. "
        "Ensure that the answer is exhaustive, leaves no room for follow-up questions, "
        "and maintains a professional, approachable tone."
    ),
    tools=[docs_scrape_tool],
    agent=customer_assist_agent,
)

# %%
response_review_task = Task(
    description=(
        "Evaluate the response prepared by the Customer Care Specialist for {customer}'s inquiry. "
        "Ensure the reply meets the highest standards of accuracy, completeness, and clarity "
        "expected in customer service.\n"
        "Confirm that every aspect of the customer's question has been addressed "
        "in a friendly and approachable manner.\n"
        "Verify the inclusion of appropriate references and sources used "
        "to gather the information, ensuring the response is well-supported and "
        "leaves no loose ends."
    ),
    expected_output=(
        "A polished, detailed, and ready-to-send response that completely addresses "
        "the customer's inquiry.\n"
        "The response should reflect all necessary feedback and adjustments while "
        "maintaining a relaxed yet professional tone that aligns with our cool and casual company culture."
    ),
    agent=quality_check_agent,
)

# %%
crewCSMAS = Crew(
  agents=[customer_assist_agent, quality_check_agent],
  tasks=[customer_query_task, response_review_task],
  verbose=True,
  memory=True
)

# %%
inputs = {
    "customer": "Unfold data science",
    "person": "Aman Kumar",
    "inquiry": "I need help with Crew AI "
               "and Understanding about Crew and Agent "
               "How to use Crew and Agent in CrewAI "
               "Can you provide guidance?"
}
result = crewCSMAS.kickoff(inputs=inputs)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 1ed5f711-447a-43da-9c65-43c0a3ebb16c                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Unfold data science has submitted a critical request:                                                    │
# │  I need help with Crew AI and Understanding about Crew and Agent How to use Crew and Agent in CrewAI Can you    │
# │  provide guidance?                                                                                              │
# │                                                                                                                 │
# │  Aman Kumar from Unfold data science initiated the inquiry. Leverage all available resources and knowledge to   │
# │  deliver outstanding support.Your goal is to provide a thorough and accurate resolution to the customer's       │
# │  question.                                                                                                      │
# │  ID: 8fe2a429-2ba2-4603-b500-9c1ec1f6ae15                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 🧠 Memory Retrieval ──────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Memory Retrieval Started                                                                                       │
# │  Status: Retrieving...                                                                                          │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 🧠 Memory Retrieved ──────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Memory Retrieval Completed                                                                                     │
# │  Time: 6498.22ms                                                                                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Customer Care Specialist                                                                                │
# │                                                                                                                 │
# │  Task: Unfold data science has submitted a critical request:                                                    │
# │  I need help with Crew AI and Understanding about Crew and Agent How to use Crew and Agent in CrewAI Can you    │
# │  provide guidance?                                                                                              │
# │                                                                                                                 │
# │  Aman Kumar from Unfold data science initiated the inquiry. Leverage all available resources and knowledge to   │
# │  deliver outstanding support.Your goal is to provide a thorough and accurate resolution to the customer's       │
# │  question.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────── 🔧 Tool Execution Started (#1) ─────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool: read_website_content                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Tool read_website_content executed with result: The following text is scraped website content:
#
# Introduction - CrewAI Skip to main content CrewAI home page v1.10.1 English Search... ⌘ K Ask AI Start Cloud Trial crewAIInc/crewAI crewAIInc/crewAI Sea...
# ╭─────────────────────────────────────── ✅ Tool Execution Completed (#1) ────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool Completed                                                                                                 │
# │  Tool: read_website_content                                                                                     │
# │  Output: The following text is scraped website content:                                                         │
# │                                                                                                                 │
# │  Introduction - CrewAI Skip to main content CrewAI home page v1.10.1 English Search... ⌘ K Ask AI Start Cloud   │
# │  Trial crewAIInc/crewAI crewAIInc/crewAI Search... Navigation Get Started Introduction Home Documentation AMP   │
# │  API Reference Examples Changelog Website Forum Blog CrewGPT Get Started Introduction Installation Quickstart   │
# │  Guides Strategy Agents Crews Flows Coding Tools Advanced Migration Core Concepts Agents Tasks Crews Flows      │
# │  Production Architecture Knowledge LLMs Files Processes Collaboration Training Memory Reasoning Planning        │
# │  Testing CLI Tools Event Listeners MCP Integration MCP Servers as Tools in CrewAI MCP DSL Integration Stdio     │
# │  Transport SSE Transport Streamable HTTP Transport Connecting to Multiple MCP Servers MCP Security              │
# │  Considerations Tools Tools Overview File & Document Web Scraping & Browsing Search & Research Database & Data  │
# │  AI & Machine Learning Cloud & Storage Integrations Automation Observability CrewAI Tracing Overview Arize      │
# │  Phoenix Braintrust Datadog Integration Galileo LangDB Integration Langfuse Integration Langtrace Integration   │
# │  Maxim Integration MLflow Integration Neatlogs Integration OpenLIT Integration Opik Integration Patronus AI     │
# │  Evaluation Portkey Integration Weave Integration TrueFoundry Integration Learn Overview Strategic LLM          │
# │  Selection Guide Conditional Tasks Coding Agents Create Custom Tools Custom LLM Implementation Custom Manager   │
# │  Agent Customize Agents Image Generation with DALL-E Force Tool Output as Result Hierarchical Process Human     │
# │  Input on Execution Human-in-the-Loop (HITL) Workflows Human Feedback in Flows Kickoff Crew Asynchronously      │
# │  Kickoff Crew for Each Connect to any LLM Using Multimodal Agents Replay Tasks from Latest Crew Kickoff         │
# │  Sequential Processes Using Annotations in crew.py Execution Hooks Overview LLM Call Hooks Tool Call Hooks      │
# │  Telemetry Telemetry Get Started Introduction Copy page Build AI agent teams that work together to tackle       │
# │  complex tasks Copy page ​ What is CrewAI?                                                                       │
# │  CrewAI is the leading open-source framework for orchestrating autonomous AI agents and building complex        │
# │  workflows.                                                                                                     │
# │  It empowers developers to build production-ready multi-agent systems by combining the collaborative            │
# │  intelligence of Crews with the precise control of Flows .                                                      │
# │  CrewAI Flows : The backbone of your AI application. Flows allow you to create structured, event-driven         │
# │  workflows that manage state and control execution. They provide the scaffolding for your AI agents to work     │
# │  within.                                                                                                        │
# │  CrewAI Crews : The units of work within your Flow. Crews are teams of autonomous agents that collaborate to    │
# │  solve specific tasks delegated to them by the Flow.                                                            │
# │  With over 100,000 developers certified through our community courses, CrewAI is the standard for               │
# │  enterprise-ready AI automation.                                                                                │
# │  ​ The CrewAI Architecture                                                                                       │
# │  CrewAI’s architecture is designed to balance autonomy with control.                                            │
# │  ​ 1. Flows: The Backbone                                                                                        │
# │  Think of a Flow as the “manager” or the “process definition” of your application. It defines the steps, the    │
# │  logic, and how data moves through your system.                                                                 │
# │  Flows provide:                                                                                                 │
# │  State Management : Persist data across steps and executions.                                                   │
# │  Event-Driven Execution : Trigger actions based on events or external inputs.                                   │
# │  Control Flow : Use conditional logic, loops, and branching.                                                    │
# │  ​ 2. Crews: The Intelligence                                                                                    │
# │  Crews are the “teams” that do the heavy lifting. Within a Flow, you can trigger a Crew to tackle a complex     │
# │  problem requiring creativity and collaboration.                                                                │
# │  Crews provide:                                                                                                 │
# │  Role-Playing Agents : Specialized agents with specific goals and tools.                                        │
# │  Autonomous Collaboration : Agents work together to solve tasks.                                                │
# │  Task Delegation : Tasks are assigned and executed based on agent capabilities.                                 │
# │  ​ How It All Works Together                                                                                     │
# │  The Flow triggers an event or starts a process.                                                                │
# │  The Flow manages the state and decides what to do next.                                                        │
# │  The Flow delegates a complex task to a Crew .                                                                  │
# │  The Crew ’s agents collaborate to complete the task.                                                           │
# │  The Crew returns the result to the Flow .                                                                      │
# │  The Flow continues execution based on the result.                                                              │
# │  ​ Key Features                                                                                                  │
# │  Production-Grade Flows Build reliable, stateful workflows that can handle long-running processes and complex   │
# │  logic. Autonomous Crews Deploy teams of agents that can plan, execute, and collaborate to achieve high-level   │
# │  goals. Flexible Tools Connect your agents to any API, database, or local tool. Enterprise Security Designed    │
# │  with security and compliance in mind for enterprise deployments.                                               │
# │  ​ When to Use Crews vs. Flows                                                                                   │
# │  The short answer: Use both.                                                                                    │
# │  For any production-ready application, start with a Flow .                                                      │
# │  Use a Flow to define the overall structure, state, and logic of your application.                              │
# │  Use a Crew within a Flow step when you need a team of agents to perform a specific, complex task that          │
# │  requires autonomy.                                                                                             │
# │  Use Case Architecture Simple Automation Single Flow with Python tasks Complex Research Flow managing state ->  │
# │  Crew performing research Application Backend Flow handling API requests -> Crew generating content -> Flow     │
# │  saving to DB                                                                                                   │
# │  ​ Why Choose CrewAI?                                                                                            │
# │  🧠 Autonomous Operation : Agents make intelligent decisions based on their roles and available tools           │
# │  📝 Natural Interaction : Agents communicate and collaborate like human team members                            │
# │  🛠️ Extensible Design : Easy to add new tools, roles, and capabilities                                          │
# │  🚀 Production Ready : Built for reliability and scalability in real-world applications                         │
# │  🔒 Security-Focused : Designed with enterprise security requirements in mind                                   │
# │  💰 Cost-Efficient : Optimized to minimize token usage and API calls                                            │
# │  ​ Ready to Start Building?                                                                                      │
# │  Build Your First Flow Learn how to create structured, event-driven workflows with precise control over         │
# │  execution. Build Your First Crew Step-by-step tutorial to create a collaborative AI team that works together   │
# │  to solve complex problems.                                                                                     │
# │  Install CrewAI Get started with CrewAI in your development environment. Quick Start Follow our quickstart      │
# │  guide to create your first CrewAI agent and get hands-on experience. Join the Community Connect with other     │
# │  developers, get help, and share your CrewAI experiences. Was this page helpful? Yes No Installation Next ⌘ I   │
# │  website x github linkedin youtube reddit Powered by This documentation is built and hosted on Mintlify, a      │
# │  developer documentation platform Assistant Responses are generated using AI and may contain mistakes.          │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Customer Care Specialist                                                                                │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Certainly, Aman Kumar,                                                                                         │
# │                                                                                                                 │
# │  CrewAI is an open-source framework designed to orchestrate autonomous AI agents and construct complex          │
# │  workflows efficiently. Here is a comprehensive guide to understanding and using Crew and Agent within CrewAI:  │
# │                                                                                                                 │
# │  1. What is CrewAI?                                                                                             │
# │  CrewAI enables developers to build production-ready multi-agent systems by combining two main components:      │
# │  Crews and Flows. It is widely used for enterprise-ready AI automation.                                         │
# │                                                                                                                 │
# │  2. Core Concepts:                                                                                              │
# │  - Flows: They act as the backbone or manager of your AI application. Flows define steps, logic, how data       │
# │  moves, and how tasks are controlled within your system. They provide state management, event-driven            │
# │  execution, and control flow with conditional logic, loops, branching, etc.                                     │
# │  - Crews: These are teams composed of autonomous agents (Agents) within a Flow that collaborate to solve        │
# │  specific complex tasks. Agents are specialized roles equipped with specific goals and tools to handle          │
# │  delegated tasks.                                                                                               │
# │                                                                                                                 │
# │  3. How Crew and Agent Work Together:                                                                           │
# │  - A Flow triggers processes and manages the overall execution and state of the application.                    │
# │  - When a complex task arises, the Flow delegates it to a Crew.                                                 │
# │  - The Crew’s agents autonomously collaborate, utilize their specialized skills and tools, and work together    │
# │  to solve the task.                                                                                             │
# │  - The Crew then returns the task result to the Flow.                                                           │
# │  - The Flow continues the workflow based on the output received from the Crew.                                  │
# │                                                                                                                 │
# │  4. When to Use Crew vs. Flow:                                                                                  │
# │  - Use Flows to organize and manage the entire process, structure the execution logic, and handle state         │
# │  management.                                                                                                    │
# │  - Use Crews within Flows when you need a collaborative team of agents to accomplish complex and creative       │
# │  tasks requiring autonomous decision-making.                                                                    │
# │                                                                                                                 │
# │  5. Key Features:                                                                                               │
# │  - Production-grade Flows support long-running processes and complex logic.                                     │
# │  - Autonomous Crews allow multiple agents to digitally collaborate.                                             │
# │  - Flexible integration with APIs, databases, or local tools.                                                   │
# │  - Enterprise-grade security and compliance.                                                                    │
# │  - Cost-efficient token usage and API interaction optimization.                                                 │
# │                                                                                                                 │
# │  6. Getting Started:                                                                                            │
# │  - Build your first Flow to create structured, event-driven workflows.                                          │
# │  - Create your first Crew to see how teams of agents collaborate.                                               │
# │  - Follow the Quickstart guide to install and run CrewAI agents in your environment.                            │
# │  - Join the CrewAI community for support and knowledge sharing.                                                 │
# │                                                                                                                 │
# │  In summary, CrewAI’s design balances autonomy (with Crews and Agents) and control (with Flows), allowing you   │
# │  to build scalable, secure, and efficient AI-driven automation workflows.                                       │
# │                                                                                                                 │
# │  For more detailed technical guidance including examples and installation, you may visit the official CrewAI    │
# │  documentation at https://docs.crewai.com/introduction.                                                         │
# │                                                                                                                 │
# │  Should you need further assistance or step-by-step tutorials, please feel free to ask!                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 🧠 Memory Save ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Memory Save Started                                                                                            │
# │  Status: Saving...                                                                                              │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Unfold data science has submitted a critical request:                                                    │
# │  I need help with Crew AI and Understanding about Crew and Agent How to use Crew and Agent in CrewAI Can you    │
# │  provide guidance?                                                                                              │
# │                                                                                                                 │
# │  Aman Kumar from Unfold data science initiated the inquiry. Leverage all available resources and knowledge to   │
# │  deliver outstanding support.Your goal is to provide a thorough and accurate resolution to the customer's       │
# │  question.                                                                                                      │
# │  Agent: Customer Care Specialist                                                                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Evaluate the response prepared by the Customer Care Specialist for Unfold data science's inquiry.        │
# │  Ensure the reply meets the highest standards of accuracy, completeness, and clarity expected in customer       │
# │  service.                                                                                                       │
# │  Confirm that every aspect of the customer's question has been addressed in a friendly and approachable         │
# │  manner.                                                                                                        │
# │  Verify the inclusion of appropriate references and sources used to gather the information, ensuring the        │
# │  response is well-supported and leaves no loose ends.                                                           │
# │  ID: 683fba42-f2f1-477d-9d73-67265c3f5680                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 🧠 Memory Retrieval ──────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Memory Retrieval Started                                                                                       │
# │  Status: Retrieving...                                                                                          │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── ✅ Memory Saved ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Memory Save Completed                                                                                          │
# │  Source: Unified Memory                                                                                         │
# │  Time: 4362.40ms                                                                                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 🧠 Memory Retrieved ──────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Memory Retrieval Completed                                                                                     │
# │  Time: 9440.67ms                                                                                                │
# │  Content:                                                                                                       │
# │  Relevant memories:                                                                                             │
# │  - (score=0.77) Aman Kumar from Unfold data science initiated an inquiry regarding Crew AI and how to use Crew  │
# │  and Agent in CrewAI.                                                                                           │
# │    categories: data science, AI inquiry                                                                         │
# │    entities: ['Aman Kumar', 'Unfold data science', 'Crew AI', 'Crew', 'Agent']                                  │
# │    dates: []                                                                                                    │
# │    topics: ['inquiry', 'data science', 'AI']                                                                    │
# │  - (score=0.76) When a complex task arises, the Flow delegates it to a Crew who then solves the task and        │
# │  returns the result to the Flow.                                                                                │
# │    categories: workflow, delegation, team collaboration                                                         │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['complex tasks', 'delegation', 'crew management']                                                   │
# │  - (score=0.76) The official CrewAI documentation can be found at https://docs.crewai.com/introduction.         │
# │    categories: documentation                                                                                    │
# │    entities: ['CrewAI']                                                                                         │
# │    dates: []                                                                                                    │
# │    topics: ['documentation', 'AI tools', 'technology']                                                          │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Support Quality Analyst                                                                                 │
# │                                                                                                                 │
# │  Task: Evaluate the response prepared by the Customer Care Specialist for Unfold data science's inquiry.        │
# │  Ensure the reply meets the highest standards of accuracy, completeness, and clarity expected in customer       │
# │  service.                                                                                                       │
# │  Confirm that every aspect of the customer's question has been addressed in a friendly and approachable         │
# │  manner.                                                                                                        │
# │  Verify the inclusion of appropriate references and sources used to gather the information, ensuring the        │
# │  response is well-supported and leaves no loose ends.                                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────── 🔧 Tool Execution Started (#1) ─────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool: search_memory                                                                                            │
# │  Args: {'queries': ['Aman Kumar Crew AI inquiry response quality', 'Crew and Agent explanation by Customer      │
# │  Care Specialist', 'Customer inquiry about CrewAI detailed response', 'Unfold data science Crew AI su...        │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Tool search_memory executed with result: Found memories:
# - (score=0.85) Aman Kumar from Unfold data science initiated an inquiry regarding Crew AI and how to use Crew and Agent in CrewAI.
#   categories: data science, AI inquiry
#   entities: ['...
# ╭─────────────────────────────────────── ✅ Tool Execution Completed (#1) ────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool Completed                                                                                                 │
# │  Tool: search_memory                                                                                            │
# │  Output: Found memories:                                                                                        │
# │  - (score=0.85) Aman Kumar from Unfold data science initiated an inquiry regarding Crew AI and how to use Crew  │
# │  and Agent in CrewAI.                                                                                           │
# │    categories: data science, AI inquiry                                                                         │
# │    entities: ['Aman Kumar', 'Unfold data science', 'Crew AI', 'Crew', 'Agent']                                  │
# │    dates: []                                                                                                    │
# │    topics: ['inquiry', 'data science', 'AI']                                                                    │
# │  - (score=0.82) CrewAI is an open-source framework designed to orchestrate autonomous AI agents and construct   │
# │  complex workflows efficiently.                                                                                 │
# │    categories: AI, Open Source, Technology                                                                      │
# │    entities: ['CrewAI']                                                                                         │
# │    dates: []                                                                                                    │
# │    topics: ['autonomous AI agents', 'workflows', 'framework']                                                   │
# │  - (score=0.80) The official CrewAI documentation can be found at https://docs.crewai.com/introduction.         │
# │    categories: documentation                                                                                    │
# │    entities: ['CrewAI']                                                                                         │
# │    dates: []                                                                                                    │
# │    topics: ['documentation', 'AI tools', 'technology']                                                          │
# │  - (score=0.80) Flows define steps, logic, and how data moves within the CrewAI system, providing state         │
# │  management and control flow.                                                                                   │
# │    categories: Data Management, Software Development, System Design                                             │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['flows', 'data movement', 'state management', 'control flow', 'CrewAI']                             │
# │  - (score=0.78) Crews are teams composed of autonomous agents within a Flow that collaborate to solve specific  │
# │  complex tasks.                                                                                                 │
# │    categories: autonomous agents, collaboration, complex tasks                                                  │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['teams', 'autonomous agents', 'collaboration', 'task management']                                   │
# │  - (score=0.78) Production-grade Flows support long-running processes and complex logic, while autonomous       │
# │  Crews allow multiple agents to collaborate.                                                                    │
# │    categories: technology, workflow, collaboration                                                              │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['long-running processes', 'complex logic', 'collaborative agents']                                  │
# │  - (score=0.78) When a complex task arises, the Flow delegates it to a Crew who then solves the task and        │
# │  returns the result to the Flow.                                                                                │
# │    categories: workflow, delegation, team collaboration                                                         │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['complex tasks', 'delegation', 'crew management']                                                   │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Support Quality Analyst                                                                                 │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Certainly, Aman Kumar,                                                                                         │
# │                                                                                                                 │
# │  Thank you for your inquiry about CrewAI and how to use Crew and Agent within the framework. I’m glad to        │
# │  provide a detailed overview to help you understand how these components work together to empower your AI       │
# │  workflows.                                                                                                     │
# │                                                                                                                 │
# │  CrewAI is an open-source framework specifically designed to orchestrate autonomous AI agents and efficiently   │
# │  manage complex workflows. It is widely adopted for enterprise-ready AI automation.                             │
# │                                                                                                                 │
# │  Here’s a comprehensive summary:                                                                                │
# │                                                                                                                 │
# │  1. What is CrewAI?                                                                                             │
# │  CrewAI allows developers to build production-ready multi-agent systems using two primary components: Crews     │
# │  and Flows.                                                                                                     │
# │                                                                                                                 │
# │  2. Core Concepts:                                                                                              │
# │  - Flows: These act as the backbone of your AI application. Flows define steps, logic, data movement, and task  │
# │  control. They support state management, event-driven execution, and complex control structures such as         │
# │  conditional logic, loops, and branching.                                                                       │
# │  - Crews: Crews are teams of autonomous Agents within a Flow. Each Agent has specialized roles and tools,       │
# │  collaborating autonomously to solve complex tasks delegated by the Flow.                                       │
# │                                                                                                                 │
# │  3. How Crew and Agent Work Together:                                                                           │
# │  - The Flow manages the overall execution and state of the application.                                         │
# │  - When the Flow encounters a complex task, it delegates it to a Crew.                                          │
# │  - The Crew’s agents collaborate autonomously, utilizing their specialized skills to resolve the task.          │
# │  - The Crew returns the results to the Flow.                                                                    │
# │  - The Flow then continues the workflow based on the output received.                                           │
# │                                                                                                                 │
# │  4. When to Use Crew vs. Flow:                                                                                  │
# │  - Use Flows to organize and manage the entire process, structure execution logic, and handle state             │
# │  management.                                                                                                    │
# │  - Use Crews within Flows when you need a collaborative team of agents to accomplish complex and creative       │
# │  tasks that require autonomous decision-making.                                                                 │
# │                                                                                                                 │
# │  5. Key Features:                                                                                               │
# │  - Production-grade Flows capable of long-running processes and complex logic.                                  │
# │  - Autonomous Crews enabling multi-agent collaboration.                                                         │
# │  - Seamless integration with APIs, databases, or local software tools.                                          │
# │  - Enterprise-grade security, compliance, and cost-efficient token and API usage.                               │
# │                                                                                                                 │
# │  6. Getting Started:                                                                                            │
# │  - Begin by building a Flow to create your structured workflows.                                                │
# │  - Create your first Crew to experience agent collaboration in action.                                          │
# │  - Follow the Quickstart guide in the CrewAI documentation to install and run agents in your environment.       │
# │  - Join the CrewAI community to connect with other users and access support.                                    │
# │                                                                                                                 │
# │  For detailed technical guidance, examples, installation instructions, and tutorials, please visit our          │
# │  official CrewAI documentation at https://docs.crewai.com/introduction.                                         │
# │                                                                                                                 │
# │  If you have any more questions or need step-by-step assistance, feel free to reach out. We’re here to help     │
# │  you make the most of CrewAI for your data science and AI projects.                                             │
# │                                                                                                                 │
# │  Best regards,                                                                                                  │
# │  [Your Name]                                                                                                    │
# │  Customer Care Specialist                                                                                       │
# │  CrewAI Team                                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Evaluate the response prepared by the Customer Care Specialist for Unfold data science's inquiry.        │
# │  Ensure the reply meets the highest standards of accuracy, completeness, and clarity expected in customer       │
# │  service.                                                                                                       │
# │  Confirm that every aspect of the customer's question has been addressed in a friendly and approachable         │
# │  manner.                                                                                                        │
# │  Verify the inclusion of appropriate references and sources used to gather the information, ensuring the        │
# │  response is well-supported and leaves no loose ends.                                                           │
# │  Agent: Support Quality Analyst                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 🧠 Memory Save ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Memory Save Started                                                                                            │
# │  Status: Saving...                                                                                              │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 1ed5f711-447a-43da-9c65-43c0a3ebb16c                                                                       │
# │  Final Output: Certainly, Aman Kumar,                                                                           │
# │                                                                                                                 │
# │  Thank you for your inquiry about CrewAI and how to use Crew and Agent within the framework. I’m glad to        │
# │  provide a detailed overview to help you understand how these components work together to empower your AI       │
# │  workflows.                                                                                                     │
# │                                                                                                                 │
# │  CrewAI is an open-source framework specifically designed to orchestrate autonomous AI agents and efficiently   │
# │  manage complex workflows. It is widely adopted for enterprise-ready AI automation.                             │
# │                                                                                                                 │
# │  Here’s a comprehensive summary:                                                                                │
# │                                                                                                                 │
# │  1. What is CrewAI?                                                                                             │
# │  CrewAI allows developers to build production-ready multi-agent systems using two primary components: Crews     │
# │  and Flows.                                                                                                     │
# │                                                                                                                 │
# │  2. Core Concepts:                                                                                              │
# │  - Flows: These act as the backbone of your AI application. Flows define steps, logic, data movement, and task  │
# │  control. They support state management, event-driven execution, and complex control structures such as         │
# │  conditional logic, loops, and branching.                                                                       │
# │  - Crews: Crews are teams of autonomous Agents within a Flow. Each Agent has specialized roles and tools,       │
# │  collaborating autonomously to solve complex tasks delegated by the Flow.                                       │
# │                                                                                                                 │
# │  3. How Crew and Agent Work Together:                                                                           │
# │  - The Flow manages the overall execution and state of the application.                                         │
# │  - When the Flow encounters a complex task, it delegates it to a Crew.                                          │
# │  - The Crew’s agents collaborate autonomously, utilizing their specialized skills to resolve the task.          │
# │  - The Crew returns the results to the Flow.                                                                    │
# │  - The Flow then continues the workflow based on the output received.                                           │
# │                                                                                                                 │
# │  4. When to Use Crew vs. Flow:                                                                                  │
# │  - Use Flows to organize and manage the entire process, structure execution logic, and handle state             │
# │  management.                                                                                                    │
# │  - Use Crews within Flows when you need a collaborative team of agents to accomplish complex and creative       │
# │  tasks that require autonomous decision-making.                                                                 │
# │                                                                                                                 │
# │  5. Key Features:                                                                                               │
# │  - Production-grade Flows capable of long-running processes and complex logic.                                  │
# │  - Autonomous Crews enabling multi-agent collaboration.                                                         │
# │  - Seamless integration with APIs, databases, or local software tools.                                          │
# │  - Enterprise-grade security, compliance, and cost-efficient token and API usage.                               │
# │                                                                                                                 │
# │  6. Getting Started:                                                                                            │
# │  - Begin by building a Flow to create your structured workflows.                                                │
# │  - Create your first Crew to experience agent collaboration in action.                                          │
# │  - Follow the Quickstart guide in the CrewAI documentation to install and run agents in your environment.       │
# │  - Join the CrewAI community to connect with other users and access support.                                    │
# │                                                                                                                 │
# │  For detailed technical guidance, examples, installation instructions, and tutorials, please visit our          │
# │  official CrewAI documentation at https://docs.crewai.com/introduction.                                         │
# │                                                                                                                 │
# │  If you have any more questions or need step-by-step assistance, feel free to reach out. We’re here to help     │
# │  you make the most of CrewAI for your data science and AI projects.                                             │
# │                                                                                                                 │
# │  Best regards,                                                                                                  │
# │  [Your Name]                                                                                                    │
# │  Customer Care Specialist                                                                                       │
# │  CrewAI Team                                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── ✅ Memory Saved ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Memory Save Completed                                                                                          │
# │  Source: Unified Memory                                                                                         │
# │  Time: 9645.12ms                                                                                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
