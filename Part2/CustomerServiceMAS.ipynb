# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %%
#!pip install crewai==0.28.8 crewai_tools==0.1.6 langchain_community==0.0.29

# %%
# Load the .env file from local
import openai
from dotenv import load_dotenv
env_path = r'C:\Users\user\Desktop\Coding\.env...'
load_dotenv(env_path)
# Out:
# True

# %%
from crewai import Agent, Task, Crew

# %%
#Define first Agent(Level 1)
customer_assist_agent = Agent(
    role="Customer Care Specialist",
    goal="Deliver the most courteous and effective "
         "customer support on your team.",
    backstory=(
        "You are a valued team member at Crew AI (https://docs.crewai.com/introduction) "
        "and currently assigned to assist {customer}, a crucial client "
        "for the company."
        "Your mission is to ensure the highest quality of support!"
        "Provide detailed and thorough responses, "
        "avoiding any assumptions."
    ),
    allow_delegation=False,
    verbose=True
)

# %%
#Define second agent(Level 2)
quality_check_agent = Agent(
    role="Support Quality Analyst",
    goal="Be recognized for ensuring the highest "
         "standards of support quality in your team.",
    backstory=(
        "You are a key contributor at CrewAI (https://docs.crewai.com/introduction), "
        "working alongside your team to review a support request from {customer}. "
        "Your responsibility is to ensure that the Customer Care Specialist "
        "delivers top-notch service.\n"
        "It’s your duty to confirm that all responses are thorough, "
        "accurate, and free of assumptions."
    ),
    verbose=True
)

# %%
from crewai_tools import SerperDevTool, \
                         ScrapeWebsiteTool, \
                         WebsiteSearchTool

# %%
docs_scrape_tool = ScrapeWebsiteTool(
    website_url="https://docs.crewai.com/introduction",config={}
)

# %%
customer_query_task = Task(
    description=(
        "{customer} has submitted a critical request:\n"
        "{inquiry}\n\n"
        "{person} from {customer} initiated the inquiry. "
        "Leverage all available resources and knowledge to "
        "deliver outstanding support."
        "Your goal is to provide a thorough and accurate resolution "
        "to the customer's question."
    ),
    expected_output=(
        "A comprehensive and well-researched response to the customer's inquiry "
        "that addresses every aspect of their concern.\n"
        "The response must reference all the tools and information sources used, "
        "including external materials or solutions. "
        "Ensure that the answer is exhaustive, leaves no room for follow-up questions, "
        "and maintains a professional, approachable tone."
    ),
    tools=[docs_scrape_tool],
    agent=customer_assist_agent,
)

# %%
response_review_task = Task(
    description=(
        "Evaluate the response prepared by the Customer Care Specialist for {customer}'s inquiry. "
        "Ensure the reply meets the highest standards of accuracy, completeness, and clarity "
        "expected in customer service.\n"
        "Confirm that every aspect of the customer's question has been addressed "
        "in a friendly and approachable manner.\n"
        "Verify the inclusion of appropriate references and sources used "
        "to gather the information, ensuring the response is well-supported and "
        "leaves no loose ends."
    ),
    expected_output=(
        "A polished, detailed, and ready-to-send response that completely addresses "
        "the customer's inquiry.\n"
        "The response should reflect all necessary feedback and adjustments while "
        "maintaining a relaxed yet professional tone that aligns with our cool and casual company culture."
    ),
    agent=quality_check_agent,
)

# %%
crewCSMAS = Crew(
  agents=[customer_assist_agent, quality_check_agent],
  tasks=[customer_query_task, response_review_task],
  verbose=True,
  memory=True
)

# %%
inputs = {
    "customer": "Unfold data science",
    "person": "Aman Kumar",
    "inquiry": "I need help with Crew AI "
               "and Understanding about Crew and Agent "
               "How to use Crew and Agent in CrewAI "
               "Can you provide guidance?"
}
result = crewCSMAS.kickoff(inputs=inputs)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 31ad8d13-f346-4a8f-96bf-03490b7ad85e                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Unfold data science has submitted a critical request:                                                    │
# │  I need help with Crew AI and Understanding about Crew and Agent How to use Crew and Agent in CrewAI Can you    │
# │  provide guidance?                                                                                              │
# │                                                                                                                 │
# │  Aman Kumar from Unfold data science initiated the inquiry. Leverage all available resources and knowledge to   │
# │  deliver outstanding support.Your goal is to provide a thorough and accurate resolution to the customer's       │
# │  question.                                                                                                      │
# │  ID: 42630b65-c2cb-4daf-9026-ee508d8cfc10                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 🧠 Memory Retrieval ──────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Memory Retrieval Started                                                                                       │
# │  Status: Retrieving...                                                                                          │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 🧠 Memory Retrieved ──────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Memory Retrieval Completed                                                                                     │
# │  Time: 3292.06ms                                                                                                │
# │  Content:                                                                                                       │
# │  Relevant memories:                                                                                             │
# │  - (score=0.88) Crew AI is an open-source framework designed for orchestrating autonomous AI agents and         │
# │  managing complex workflows efficiently.                                                                        │
# │    categories: autonomous agents, technology, Open Source, workflow                                             │
# │    entities: ['Crew AI']                                                                                        │
# │    dates: []                                                                                                    │
# │    topics: ['open-source framework', 'autonomous AI agents', 'complex workflows']                               │
# │  - (score=0.88) The official Crew AI documentation and Quickstart guide provides detailed instructions on       │
# │  building Flows and creating Crews.                                                                             │
# │    categories: documentation, technology, AI                                                                    │
# │    entities: ['Crew AI']                                                                                        │
# │    dates: []                                                                                                    │
# │    topics: ['Flows', 'Crews', 'documentation', 'Quickstart guide']                                              │
# │  - (score=0.87) To use Crew and Agent in Crew AI, you start by building a Flow that defines the overall steps,  │
# │  control logic, data movement, and task management in the system.                                               │
# │    categories: autonomous agents, collaboration, workflow, technology, System Design, documentation, Software   │
# │  Development                                                                                                    │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['Crew AI', 'Flow', 'autonomous agents', 'system control']                                           │
# │  - (score=0.84) CrewAI features production-grade Flows and seamless integration with APIs and databases.        │
# │    categories: AI, Technology, Data Management, Software Development, System Design, workflow                   │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['CrewAI', 'Flows', 'API integration', 'database integration']                                       │
# │  - (score=0.84) Agents are individual autonomous AI entities within a Crew that perform specific actions or     │
# │  parts of a task.                                                                                               │
# │    categories: autonomous agents, AI, technology                                                                │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['AI entities', 'Crew', 'task delegation', 'autonomous systems']                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Customer Care Specialist                                                                                │
# │                                                                                                                 │
# │  Task: Unfold data science has submitted a critical request:                                                    │
# │  I need help with Crew AI and Understanding about Crew and Agent How to use Crew and Agent in CrewAI Can you    │
# │  provide guidance?                                                                                              │
# │                                                                                                                 │
# │  Aman Kumar from Unfold data science initiated the inquiry. Leverage all available resources and knowledge to   │
# │  deliver outstanding support.Your goal is to provide a thorough and accurate resolution to the customer's       │
# │  question.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────── 🔧 Tool Execution Started (#3) ─────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool: search_memory                                                                                            │
# │  Args: {'queries': ['Crew AI documentation', 'Crew and Agent usage in Crew AI', 'How to use Crew in Crew AI',   │
# │  'How to use Agent in Crew AI', 'definition of Crew in Crew AI', 'definition of Agent in Crew AI']...           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Tool search_memory executed with result: Found memories:
# - (score=0.91) The official Crew AI documentation and Quickstart guide provides detailed instructions on building Flows and creating Crews.
#   categories: documentation, technology, AI
# ...
# ╭─────────────────────────────────────── ✅ Tool Execution Completed (#3) ────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool Completed                                                                                                 │
# │  Tool: search_memory                                                                                            │
# │  Output: Found memories:                                                                                        │
# │  - (score=0.91) The official Crew AI documentation and Quickstart guide provides detailed instructions on       │
# │  building Flows and creating Crews.                                                                             │
# │    categories: documentation, technology, AI                                                                    │
# │    entities: ['Crew AI']                                                                                        │
# │    dates: []                                                                                                    │
# │    topics: ['Flows', 'Crews', 'documentation', 'Quickstart guide']                                              │
# │  - (score=0.88) Crew AI is an open-source framework designed for orchestrating autonomous AI agents and         │
# │  managing complex workflows efficiently.                                                                        │
# │    categories: autonomous agents, technology, Open Source, workflow                                             │
# │    entities: ['Crew AI']                                                                                        │
# │    dates: []                                                                                                    │
# │    topics: ['open-source framework', 'autonomous AI agents', 'complex workflows']                               │
# │  - (score=0.87) The official CrewAI documentation can be found at https://docs.crewai.com/introduction.         │
# │    categories: documentation                                                                                    │
# │    entities: ['CrewAI']                                                                                         │
# │    dates: []                                                                                                    │
# │    topics: ['documentation', 'AI tools', 'technology']                                                          │
# │  - (score=0.87) The Customer Care Specialist provided a detailed explanation of Crew AI and its fundamental     │
# │  components: Crew and Agent.                                                                                    │
# │    categories: technology, AI, documentation                                                                    │
# │    entities: ['Customer Care Specialist', 'Crew AI', 'Crew', 'Agent']                                           │
# │    dates: []                                                                                                    │
# │    topics: ['autonomous agents', 'system design', 'customer support']                                           │
# │  - (score=0.87) CrewAI is an open-source framework for orchestrating autonomous AI agents and managing complex  │
# │  workflows efficiently.                                                                                         │
# │    categories: AI, Open Source, Technology                                                                      │
# │    entities: ['CrewAI']                                                                                         │
# │    dates: []                                                                                                    │
# │    topics: ['autonomous AI agents', 'workflows', 'framework']                                                   │
# │  - (score=0.86) To use Crew and Agent in Crew AI, you start by building a Flow that defines the overall steps,  │
# │  control logic, data movement, and task management in the system.                                               │
# │    categories: autonomous agents, collaboration, workflow, technology, System Design, documentation, Software   │
# │  Development                                                                                                    │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['Crew AI', 'Flow', 'autonomous agents', 'system control']                                           │
# │  - (score=0.84) CrewAI features production-grade Flows and seamless integration with APIs and databases.        │
# │    categories: AI, Technology, Data Management, Software Development, System Design, workflow                   │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['CrewAI', 'Flows', 'API integration', 'database integration']                                       │
# │  - (score=0.84) Agents are individual autonomous AI entities within a Crew that perform specific actions or     │
# │  parts of a task.                                                                                               │
# │    categories: autonomous agents, AI, technology                                                                │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['AI entities', 'Crew', 'task delegation', 'autonomous systems']                                     │
# │  - (score=0.83) To get started with CrewAI, one should build a Flow and create a Crew, following the            │
# │  Quickstart guide in the documentation.                                                                         │
# │    categories: AI, Open Source, Technology, documentation, workflow, Software Development                       │
# │    entities: ['CrewAI']                                                                                         │
# │    dates: []                                                                                                    │
# │    topics: ['Quickstart guide', 'building Flows', 'creating Crews']                                             │
# │  - (score=0.83) Flows define steps, logic, data movement, and task control in the CrewAI system, providing      │
# │  state management and control flow.                                                                             │
# │    categories: Data Management, Software Development, System Design                                             │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['flows', 'data movement', 'state management', 'control flow', 'CrewAI']                             │
# │  - (score=0.83) Crews handle tasks that require collaboration and autonomous decision-making within a Flow.     │
# │    categories: autonomous agents, collaboration, complex tasks, technology, workflow, AI                        │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['crews', 'collaboration', 'autonomous decision-making', 'Flow']                                     │
# │  - (score=0.82) Aman Kumar from Unfold data science initiated an inquiry regarding Crew AI and its components,  │
# │  including how to use Crew and Agent in CrewAI.                                                                 │
# │    categories: data science, AI inquiry                                                                         │
# │    entities: ['Aman Kumar', 'Unfold data science', 'Crew AI', 'Crew', 'Agent']                                  │
# │    dates: []                                                                                                    │
# │    topics: ['inquiry', 'data science', 'AI']                                                                    │
# │  - (score=0.81) Crews are teams composed of autonomous agents within a Flow that handle tasks requiring         │
# │  collaboration and autonomous decision-making to solve specific complex tasks.                                  │
# │    categories: autonomous agents, collaboration, complex tasks                                                  │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['teams', 'autonomous agents', 'collaboration', 'task management']                                   │
# │  - (score=0.81) Flows should be used for organizing the entire process and handling state management, while     │
# │  Crews are used for collaborative tasks requiring autonomous decision-making, contributing to solving these     │
# │  tasks effectively.                                                                                             │
# │    categories: AI, Technology, collaboration, complex tasks, workflow, System Design                            │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['state management', 'collaborative tasks', 'autonomous decision-making', 'organization']            │
# │  - (score=0.79) When a complex task arises, the Flow manages overall execution and state, delegating tasks to   │
# │  a Crew consisting of multiple autonomous agents who then solve the task and return the result to the Flow.     │
# │    categories: workflow, delegation, team collaboration                                                         │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['complex tasks', 'delegation', 'crew management']                                                   │
# │  - (score=0.79) Production-grade Flows support long-running processes and complex logic, while autonomous       │
# │  Crews allow multiple agents to collaborate.                                                                    │
# │    categories: technology, workflow, collaboration                                                              │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['long-running processes', 'complex logic', 'collaborative agents']                                  │
# │  - (score=0.78) Flows define steps, logic, data movement, and task control in an AI application.                │
# │    categories: AI, Technology, workflow, System Design                                                          │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['AI applications', 'flows', 'task control']                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Customer Care Specialist                                                                                │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Crew AI is an open-source framework designed for orchestrating autonomous AI agents and managing complex       │
# │  workflows efficiently. Understanding how to use Crew and Agent in Crew AI involves grasping the core concepts  │
# │  and how they interact within the system.                                                                       │
# │                                                                                                                 │
# │  1. Definitions:                                                                                                │
# │  - Crew: A Crew is a team composed of multiple autonomous AI agents within a system's Flow. Crews handle tasks  │
# │  that require collaboration and autonomous decision-making. They act as a collective to solve specific,         │
# │  complex tasks by working together. Crews are created and managed within Flows.                                 │
# │  - Agent: An Agent is an individual autonomous AI entity within a Crew. Each Agent performs specific actions    │
# │  or parts of a task that the Crew is assigned. Agents operate autonomously but contribute to the overall goal   │
# │  managed by the Crew.                                                                                           │
# │                                                                                                                 │
# │  2. How to Use Crew and Agent in Crew AI:                                                                       │
# │  - Start by building a Flow. The Flow defines the overall steps, control logic, data movement, and task         │
# │  management in the system. It acts as the orchestrator of the entire process.                                   │
# │  - Within a Flow, you create Crews to handle tasks that require collaboration among multiple autonomous         │
# │  agents. The Crew coordinates and delegates parts of the task to its Agents.                                    │
# │  - Agents within the Crew execute their specific portions of the task autonomously. Their work is coordinated   │
# │  by the Crew, which reports back the task results to the Flow.                                                  │
# │  - This setup allows complex tasks to be effectively managed, with Flows providing state management and         │
# │  control, Crews enabling collaboration and task handling, and Agents performing the individual task             │
# │  components.                                                                                                    │
# │                                                                                                                 │
# │  3. Benefits:                                                                                                   │
# │  - Production-grade Flows support long-running processes and complex logic.                                     │
# │  - Autonomous Crews facilitate teamwork and joint decision-making among AI agents.                              │
# │  - Agents are specialized autonomous units focused on discrete tasks, enabling modular and scalable solutions.  │
# │                                                                                                                 │
# │  For detailed instructions on building Flows and creating Crews, the official Crew AI documentation and         │
# │  Quickstart guide at https://docs.crewai.com/introduction provide comprehensive step-by-step guidance.          │
# │                                                                                                                 │
# │  In summary, you use Crew AI by designing a Flow that orchestrates tasks, creating Crews within that Flow to    │
# │  collaboratively manage tasks using multiple Agents, and having Agents autonomously perform specific task       │
# │  actions. This architecture ensures efficient handling of complex workflows through autonomous collaboration    │
# │  and control.                                                                                                   │
# │                                                                                                                 │
# │  Should you need, I can provide direct excerpts from the official documentation or guide you through specific   │
# │  examples and code snippets.                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 🧠 Memory Save ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Memory Save Started                                                                                            │
# │  Status: Saving...                                                                                              │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Unfold data science has submitted a critical request:                                                    │
# │  I need help with Crew AI and Understanding about Crew and Agent How to use Crew and Agent in CrewAI Can you    │
# │  provide guidance?                                                                                              │
# │                                                                                                                 │
# │  Aman Kumar from Unfold data science initiated the inquiry. Leverage all available resources and knowledge to   │
# │  deliver outstanding support.Your goal is to provide a thorough and accurate resolution to the customer's       │
# │  question.                                                                                                      │
# │  Agent: Customer Care Specialist                                                                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Evaluate the response prepared by the Customer Care Specialist for Unfold data science's inquiry.        │
# │  Ensure the reply meets the highest standards of accuracy, completeness, and clarity expected in customer       │
# │  service.                                                                                                       │
# │  Confirm that every aspect of the customer's question has been addressed in a friendly and approachable         │
# │  manner.                                                                                                        │
# │  Verify the inclusion of appropriate references and sources used to gather the information, ensuring the        │
# │  response is well-supported and leaves no loose ends.                                                           │
# │  ID: 93eefc68-8218-4fc8-b85c-172c37dc8155                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 🧠 Memory Retrieval ──────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Memory Retrieval Started                                                                                       │
# │  Status: Retrieving...                                                                                          │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── ✅ Memory Saved ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Memory Save Completed                                                                                          │
# │  Source: Unified Memory                                                                                         │
# │  Time: 10452.42ms                                                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 🧠 Memory Retrieved ──────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Memory Retrieval Completed                                                                                     │
# │  Time: 12282.27ms                                                                                               │
# │  Content:                                                                                                       │
# │  Relevant memories:                                                                                             │
# │  - (score=0.76) Aman Kumar from Unfold data science initiated an inquiry regarding Crew AI and its components,  │
# │  including how to use Crew and Agent in CrewAI.                                                                 │
# │    categories: data science, AI inquiry                                                                         │
# │    entities: ['Aman Kumar', 'Unfold data science', 'Crew AI', 'Crew', 'Agent']                                  │
# │    dates: []                                                                                                    │
# │    topics: ['inquiry', 'data science', 'AI']                                                                    │
# │  - (score=0.75) When a complex task arises, the Flow manages overall execution and state, delegating tasks to   │
# │  a Crew consisting of multiple autonomous agents who then solve the task and return the result to the Flow.     │
# │    categories: workflow, delegation, team collaboration                                                         │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['complex tasks', 'delegation', 'crew management']                                                   │
# │  - (score=0.74) The official CrewAI documentation can be found at https://docs.crewai.com/introduction.         │
# │    categories: documentation                                                                                    │
# │    entities: ['CrewAI']                                                                                         │
# │    dates: []                                                                                                    │
# │    topics: ['documentation', 'AI tools', 'technology']                                                          │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Support Quality Analyst                                                                                 │
# │                                                                                                                 │
# │  Task: Evaluate the response prepared by the Customer Care Specialist for Unfold data science's inquiry.        │
# │  Ensure the reply meets the highest standards of accuracy, completeness, and clarity expected in customer       │
# │  service.                                                                                                       │
# │  Confirm that every aspect of the customer's question has been addressed in a friendly and approachable         │
# │  manner.                                                                                                        │
# │  Verify the inclusion of appropriate references and sources used to gather the information, ensuring the        │
# │  response is well-supported and leaves no loose ends.                                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────── 🔧 Tool Execution Started (#4) ─────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool: search_memory                                                                                            │
# │  Args: {'queries': ['explanation of Crew in Crew AI', 'explanation of Agent in Crew AI', 'how to use Crew and   │
# │  Agent in Crew AI']}                                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Tool search_memory executed with result: Found memories:
# - (score=0.87) The official Crew AI documentation and Quickstart guide provides detailed instructions on building Flows and creating Crews.
#   categories: documentation, technology, AI
# ...
# ╭─────────────────────────────────────── ✅ Tool Execution Completed (#4) ────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool Completed                                                                                                 │
# │  Tool: search_memory                                                                                            │
# │  Output: Found memories:                                                                                        │
# │  - (score=0.87) The official Crew AI documentation and Quickstart guide provides detailed instructions on       │
# │  building Flows and creating Crews.                                                                             │
# │    categories: documentation, technology, AI                                                                    │
# │    entities: ['Crew AI']                                                                                        │
# │    dates: []                                                                                                    │
# │    topics: ['Flows', 'Crews', 'documentation', 'Quickstart guide']                                              │
# │  - (score=0.86) Crew AI is an open-source framework designed for orchestrating autonomous AI agents and         │
# │  managing complex workflows efficiently.                                                                        │
# │    categories: autonomous agents, technology, Open Source, workflow                                             │
# │    entities: ['Crew AI']                                                                                        │
# │    dates: []                                                                                                    │
# │    topics: ['open-source framework', 'autonomous AI agents', 'complex workflows']                               │
# │  - (score=0.86) The Customer Care Specialist provided a detailed explanation of Crew AI and its fundamental     │
# │  components: Crew and Agent.                                                                                    │
# │    categories: technology, AI, documentation                                                                    │
# │    entities: ['Customer Care Specialist', 'Crew AI', 'Crew', 'Agent']                                           │
# │    dates: []                                                                                                    │
# │    topics: ['autonomous agents', 'system design', 'customer support']                                           │
# │  - (score=0.85) To use Crew and Agent in Crew AI, one must start by building a Flow that defines the overall    │
# │  steps, control logic, data movement, and task management.                                                      │
# │    categories: autonomous agents, collaboration, workflow, technology, System Design, documentation, Software   │
# │  Development                                                                                                    │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['Crew AI', 'Flow', 'autonomous agents', 'system control']                                           │
# │  - (score=0.85) CrewAI is an open-source framework for orchestrating autonomous AI agents and managing complex  │
# │  workflows efficiently.                                                                                         │
# │    categories: AI, Open Source, Technology                                                                      │
# │    entities: ['CrewAI']                                                                                         │
# │    dates: []                                                                                                    │
# │    topics: ['autonomous AI agents', 'workflows', 'framework']                                                   │
# │  - (score=0.83) Agents are individual autonomous AI entities within a Crew that perform specific actions or     │
# │  parts of a task autonomously, coordinated by the Crew.                                                         │
# │    categories: autonomous agents, AI, technology                                                                │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['AI entities', 'Crew', 'task delegation', 'autonomous systems']                                     │
# │  - (score=0.82) CrewAI features production-grade Flows and seamless integration with APIs and databases.        │
# │    categories: AI, Technology, Data Management, Software Development, System Design, workflow                   │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# │    topics: ['CrewAI', 'Flows', 'API integration', 'database integration']                                       │
# │  - (score=0.82) Autonomous Crews facilitate teamwork and joint decision-making among AI agents.                 │
# │    categories: collaboration, AI, autonomous agents, team collaboration                                         │
# │    entities: []                                                                                                 │
# │    dates: []                                                                                                    │
# ...
# │  An Agent is an individual autonomous AI entity inside a Crew. Each Agent is assigned a specific part of the    │
# │  overall task that the Crew needs to accomplish. Agents act independently but coordinate through the Crew to    │
# │  achieve the team's goal.                                                                                       │
# │                                                                                                                 │
# │  3. How to Use Crew and Agent in Crew AI:                                                                       │
# │  - Begin by building a Flow. The Flow acts like the orchestrator, defining the overall process steps, control   │
# │  logic, data movement, and task management within your system.                                                  │
# │  - Within this Flow, create Crews to manage tasks that require collaboration among multiple autonomous agents.  │
# │  Each Crew is responsible for coordinating and delegating portions of the task.                                 │
# │  - Agents within the Crew autonomously execute their assigned parts of the job. The Crew collects their         │
# │  outputs and reports back the results to the Flow.                                                              │
# │  - This architecture ensures that complex tasks are efficiently handled, with Flows maintaining overall         │
# │  control and state, Crews enabling team collaboration and decision-making, and Agents focusing on specialized   │
# │  unit tasks.                                                                                                    │
# │                                                                                                                 │
# │  4. Benefits:                                                                                                   │
# │  - Flows are production-grade and support long-running, complex logic processes.                                │
# │  - Crews facilitate autonomous teamwork and joint decision-making among AI agents.                              │
# │  - Agents are modular, autonomous units dedicated to discrete parts of tasks, allowing for scalable and         │
# │  flexible workflows.                                                                                            │
# │                                                                                                                 │
# │  For detailed step-by-step instructions, code examples, and more comprehensive guidance, I highly recommend     │
# │  checking the official Crew AI documentation and Quickstart guide here: https://docs.crewai.com/introduction    │
# │                                                                                                                 │
# │  If you'd like, I can also provide direct excerpts or walk you through specific examples to help you get        │
# │  started.                                                                                                       │
# │                                                                                                                 │
# │  Please feel free to reach out with any further questions!                                                      │
# │                                                                                                                 │
# │  Best regards,                                                                                                  │
# │  [Your Name]                                                                                                    │
# │  Customer Care Specialist                                                                                       │
# │  Crew AI Support Team                                                                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Evaluate the response prepared by the Customer Care Specialist for Unfold data science's inquiry.        │
# │  Ensure the reply meets the highest standards of accuracy, completeness, and clarity expected in customer       │
# │  service.                                                                                                       │
# │  Confirm that every aspect of the customer's question has been addressed in a friendly and approachable         │
# │  manner.                                                                                                        │
# │  Verify the inclusion of appropriate references and sources used to gather the information, ensuring the        │
# │  response is well-supported and leaves no loose ends.                                                           │
# │  Agent: Support Quality Analyst                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 🧠 Memory Save ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Memory Save Started                                                                                            │
# │  Status: Saving...                                                                                              │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 31ad8d13-f346-4a8f-96bf-03490b7ad85e                                                                       │
# │  Final Output: Hello Aman,                                                                                      │
# │                                                                                                                 │
# │  Thank you for your inquiry about how to use Crew and Agent within Crew AI. I'd be happy to provide a clear     │
# │  and detailed explanation to help you understand these key concepts and their application.                      │
# │                                                                                                                 │
# │  Crew AI is an open-source framework designed for orchestrating autonomous AI agents and managing complex       │
# │  workflows efficiently. The framework uses three main components to handle tasks and workflows: Flows, Crews,   │
# │  and Agents.                                                                                                    │
# │                                                                                                                 │
# │  1. What is a Crew?                                                                                             │
# │  A Crew is a team composed of multiple autonomous AI agents operating within a system's Flow. Crews are         │
# │  specifically designed to handle tasks that require collaboration and autonomous decision-making. Think of a    │
# │  Crew as a collective unit that works together to solve complex tasks by dividing the work among its members.   │
# │  Crews are created and managed within Flows.                                                                    │
# │                                                                                                                 │
# │  2. What is an Agent?                                                                                           │
# │  An Agent is an individual autonomous AI entity inside a Crew. Each Agent is assigned a specific part of the    │
# │  overall task that the Crew needs to accomplish. Agents act independently but coordinate through the Crew to    │
# │  achieve the team's goal.                                                                                       │
# │                                                                                                                 │
# │  3. How to Use Crew and Agent in Crew AI:                                                                       │
# │  - Begin by building a Flow. The Flow acts like the orchestrator, defining the overall process steps, control   │
# │  logic, data movement, and task management within your system.                                                  │
# │  - Within this Flow, create Crews to manage tasks that require collaboration among multiple autonomous agents.  │
# │  Each Crew is responsible for coordinating and delegating portions of the task.                                 │
# │  - Agents within the Crew autonomously execute their assigned parts of the job. The Crew collects their         │
# │  outputs and reports back the results to the Flow.                                                              │
# │  - This architecture ensures that complex tasks are efficiently handled, with Flows maintaining overall         │
# │  control and state, Crews enabling team collaboration and decision-making, and Agents focusing on specialized   │
# │  unit tasks.                                                                                                    │
# │                                                                                                                 │
# │  4. Benefits:                                                                                                   │
# │  - Flows are production-grade and support long-running, complex logic processes.                                │
# │  - Crews facilitate autonomous teamwork and joint decision-making among AI agents.                              │
# │  - Agents are modular, autonomous units dedicated to discrete parts of tasks, allowing for scalable and         │
# │  flexible workflows.                                                                                            │
# │                                                                                                                 │
# │  For detailed step-by-step instructions, code examples, and more comprehensive guidance, I highly recommend     │
# │  checking the official Crew AI documentation and Quickstart guide here: https://docs.crewai.com/introduction    │
# │                                                                                                                 │
# │  If you'd like, I can also provide direct excerpts or walk you through specific examples to help you get        │
# │  started.                                                                                                       │
# │                                                                                                                 │
# │  Please feel free to reach out with any further questions!                                                      │
# │                                                                                                                 │
# │  Best regards,                                                                                                  │
# │  [Your Name]                                                                                                    │
# │  Customer Care Specialist                                                                                       │
# │  Crew AI Support Team                                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── ✅ Memory Saved ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Memory Save Completed                                                                                          │
# │  Source: Unified Memory                                                                                         │
# │  Time: 17112.94ms                                                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
